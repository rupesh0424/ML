# %% [markdown]
# <a href="https://colab.research.google.com/github/rupesh0424/ML/blob/main/ML_SKILL_EXP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
?
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.3
# NumPy          : 2.1.3
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
from pandas import read_csv
df = pd.read_csv("gender_submission.csv")

# %%
df.tail(5)
# Out:
#      PassengerId  Survived
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0

# %%
df.shape
# Out:
# (418, 2)

# %%
rows, columns = df.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 418
# Number of columns: 2

# %%
df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df.dtypes
# Out:
# PassengerId    int64
# Survived       int64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64    2
# Name: count, dtype: int64

# %%
missing_data = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})

missing_data
# Out:
#              Missing Values  Percentage
# PassengerId               0         0.0
# Survived                  0         0.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# cbar=False hides the color bar; yticklabels=False hides row numbers for cleaner v
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
#Keeps the first occurrence and marks subsequent duplicates as True(if any)
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [PassengerId, Survived]
# Index: []
# ----------------------------------------

# %%
#Remove Duplicates
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (418, 2)

# %%
df.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000
